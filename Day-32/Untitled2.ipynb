# %%
num = int(input( "Enter a number:" ))
if num % 2 ==0:
  print("Even")
else:
  print("odd")
# Out:
# Enter a number:3
# odd

# %%
num = int(input("enter a number"))
if num > 0:
  print("positive")
elif num  < 0:
  print("negative")
else:
  print("zero")
# Out:
# enter a number0
# zero

# %%
n = int(input("enter a number"))
i = 1
while i <=n:
  print(i)
  i+=1
# Out:
# enter a number5
# 1
# 2
# 3
# 4
# 5

# %%
num = int(input("enter a number"))
i=1
total = 0
while i <=n:
  total +=i
  i +=1
print("Sum is:", total)
# Out:
# enter a number2
# Sum is: 15

# %%
correct_password = "1234"
attempts = 0

while attempts < 3:
    password = input("Enter password: ")

    if password == correct_password:
        print("Access Granted")
        break
    else:
        print("Wrong Password")

    attempts += 1

if attempts == 3:
    print("Access Denied")
# Out:
# Enter password: 16728
# Wrong Password
# Enter password: 1234
# Access Granted

# %%
num = int(input("enter a number: "))

i = 1
while i <=10:
  print(num, "x",i, "=", num * i)
  i += 1
# Out:
# enter a number: 4
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 4 x 10 = 40
